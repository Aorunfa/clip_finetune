# %%
import pandas as pd

# %%
df = pd.read_csv('/home/chaofeng/clip_finetune/dataset/csv/val.csv')

# %%
df
# Out:
#                                                    link  \
# 0     /home/chaofeng/clip_finetune/dataset/./data/IL...
# 1     /home/chaofeng/clip_finetune/dataset/./data/IL...
# 2     /home/chaofeng/clip_finetune/dataset/./data/IL...
# 3     /home/chaofeng/clip_finetune/dataset/./data/IL...
# 4     /home/chaofeng/clip_finetune/dataset/./data/IL...
# ...                                                 ...
# 4985  /home/chaofeng/clip_finetune/dataset/./data/IL...
# 4986  /home/chaofeng/clip_finetune/dataset/./data/IL...
# 4987  /home/chaofeng/clip_finetune/dataset/./data/IL...
# 4988  /home/chaofeng/clip_finetune/dataset/./data/IL...
# 4989  /home/chaofeng/clip_finetune/dataset/./data/IL...
#
#                         caption  type
# 0          the American lobster     0
# 1                    the Angora     0
# 2               the Appenzeller     0
# 3             the Arabian camel     0
# 4        the miniature pinscher     0
# ...                         ...   ...
# ...

# %%
df2 = pd.read_csv('/home/chaofeng/CLIP/clip/csv/val.csv')

# %%
df2
# Out:
#                                                    link           caption  \
# 0     /dev/shm/chaofeng/imagenet/data/imagenet_val/n...  the Afghan hound
# 1     /dev/shm/chaofeng/imagenet/data/imagenet_val/n...  the Afghan hound
# 2     /dev/shm/chaofeng/imagenet/data/imagenet_val/n...  the Afghan hound
# 3     /dev/shm/chaofeng/imagenet/data/imagenet_val/n...  the Afghan hound
# 4     /dev/shm/chaofeng/imagenet/data/imagenet_val/n...  the Afghan hound
# ...                                                 ...               ...
# 4985  /dev/shm/chaofeng/imagenet/data/imagenet_val/n...      the zucchini
# 4986  /dev/shm/chaofeng/imagenet/data/imagenet_val/n...      the zucchini
# 4987  /dev/shm/chaofeng/imagenet/data/imagenet_val/n...      the zucchini
# 4988  /dev/shm/chaofeng/imagenet/data/imagenet_val/n...      the zucchini
# 4989  /dev/shm/chaofeng/imagenet/data/imagenet_val/n...      the zucchini
#
#       type
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
# ...
